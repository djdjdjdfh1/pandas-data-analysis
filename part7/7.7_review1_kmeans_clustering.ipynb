# %% [markdown]
# #### K-Means k-평균 - 비지도 학습 -  군집(Cluster)
# ```
# 초기 중심점 설정 (Centroid)
# 데이터 할당(Assignment)
# 중심점 업데이트(Update)
# ```

# %%
# 6명의 학생 수학 영어점수 2개의 그룹으로 나눈다
import matplotlib.pyplot as plt
import numpy as np
X = np.array([
    [1,1],[5,5],[2,1],
    [5,4],[1,2],[6,5]
])
plt.scatter(X[:,0], X[:,1],s=100,color='gray')
plt.grid(True)
plt.show()

# %%
# 초기 중심점 할당
centroid_inital = np.array([ [1,1], [5,4]  ])

plt.scatter(X[:,0], X[:,1],s=100,color='gray',label='Data Point')
plt.scatter(centroid_inital[:,0], centroid_inital[:,1],s=100,color=['red','blue'],
            marker='X',label='initial centroid')
plt.grid(True)
plt.legend()
plt.show()

# %%
# 데이터 할당 : 모든 데이터 포인트를 순회하면서 두 중심점 중에 더 가까운 클러스터로 할당
# 빨강클러스터  p1 p2 p3
# 파랑클러스터  p4 p5 p6

# 각점이 어느 중심점에 더 가까운지 계산
label_initial = np.array([0,0,0,1,1,1])
plt.scatter(X[label_initial==0,0],X[label_initial==0,1],s=100,color='lightcoral',label='cluster1')
plt.scatter(X[label_initial==1,0],X[label_initial==1,1],s=100,color='skyblue',label='cluster2')
plt.scatter(centroid_inital[:,0], centroid_inital[:,1],s=100,color=['red','blue'],
            marker='X',label='initial centroid')
plt.grid(True)
plt.legend()
plt.show()

# %%
# 중심점 업데이트
X[label_initial==0]
c1_mean = np.mean(X[label_initial==0],axis=0)
c2_mean = np.mean(X[label_initial==1],axis=0)
centroids_updated = np.array([c1_mean,c2_mean])
print(centroids_updated)
plt.scatter(X[label_initial==0,0],X[label_initial==0,1],s=100,color='lightcoral',label='cluster1')
plt.scatter(X[label_initial==1,0],X[label_initial==1,1],s=100,color='skyblue',label='cluster2')
plt.scatter(centroid_inital[:,0], centroid_inital[:,1],s=100,color=['red','red'],
            marker='X',label='old centroids')

plt.scatter(centroids_updated[:,0], centroids_updated[:,1],s=100,color=['blue','blue'],
            marker='^',label='new centroids')
plt.legend()
# Out:
# [[2.66666667 2.33333333]
#  [4.         3.66666667]]

# %%
from sklearn.cluster import KMeans
kms = KMeans(n_clusters=2)
kms.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
kms.labels_, kms.cluster_centers_
plt.scatter(X[:, 0], X[:, 1], color='gray')
plt.scatter(kms.cluster_centers_[:, 0], kms.cluster_centers_[:, 1], color='red')
plt.show()
